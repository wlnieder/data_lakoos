# %% [markdown]
# #API

# %%
#install API connector
# !pip install binance-connector
# !pip install psycopg2
# Out:
# Requirement already satisfied: binance-connector in c:\users\mjnie\anaconda3\lib\site-packages (1.11.0)
# Requirement already satisfied: service-identity>=21.1.0 in c:\users\mjnie\anaconda3\lib\site-packages (from binance-connector) (21.1.0)
# Requirement already satisfied: requests>=2.25.1 in c:\users\mjnie\anaconda3\lib\site-packages (from binance-connector) (2.27.1)
# Requirement already satisfied: Twisted>=21.2.0 in c:\users\mjnie\anaconda3\lib\site-packages (from binance-connector) (22.2.0)
# Requirement already satisfied: pyOpenSSL>=19.0.0 in c:\users\mjnie\anaconda3\lib\site-packages (from binance-connector) (19.1.0)
# Requirement already satisfied: autobahn>=21.2.1 in c:\users\mjnie\anaconda3\lib\site-packages (from binance-connector) (22.3.2)
# Requirement already satisfied: six in c:\users\mjnie\anaconda3\lib\site-packages (from service-identity>=21.1.0->binance-connector) (1.15.0)
# Requirement already satisfied: pyasn1-modules in c:\users\mjnie\anaconda3\lib\site-packages (from service-identity>=21.1.0->binance-connector) (0.2.8)
# Requirement already satisfied: cryptography in c:\users\mjnie\anaconda3\lib\site-packages (from service-identity>=21.1.0->binance-connector) (36.0.2)
# Requirement already satisfied: pyasn1 in c:\users\mjnie\anaconda3\lib\site-packages (from service-identity>=21.1.0->binance-connector) (0.4.8)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\mjnie\anaconda3\lib\site-packages (from service-identity>=21.1.0->binance-connector) (20.3.0)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\mjnie\anaconda3\lib\site-packages (from requests>=2.25.1->binance-connector) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mjnie\anaconda3\lib\site-packages (from requests>=2.25.1->binance-connector) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mjnie\anaconda3\lib\site-packages (from requests>=2.25.1->binance-connector) (2020.6.20)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\mjnie\anaconda3\lib\site-packages (from requests>=2.25.1->binance-connector) (2.0.12)
# Requirement already satisfied: zope.interface>=4.4.2 in c:\users\mjnie\anaconda3\lib\site-packages (from Twisted>=21.2.0->binance-connector) (5.1.2)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\mjnie\anaconda3\lib\site-packages (from Twisted>=21.2.0->binance-connector) (21.0.0)
# Requirement already satisfied: Automat>=0.8.0 in c:\users\mjnie\anaconda3\lib\site-packages (from Twisted>=21.2.0->binance-connector) (20.2.0)
# Requirement already satisfied: incremental>=21.3.0 in c:\users\mjnie\anaconda3\lib\site-packages (from Twisted>=21.2.0->binance-connector) (21.3.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\mjnie\anaconda3\lib\site-packages (from Twisted>=21.2.0->binance-connector) (3.7.4.3)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2; platform_system == "Windows" in c:\users\mjnie\anaconda3\lib\site-packages (from Twisted>=21.2.0->binance-connector) (1.0.2)
# Requirement already satisfied: constantly>=15.1 in c:\users\mjnie\anaconda3\lib\site-packages (from Twisted>=21.2.0->binance-connector) (15.1.0)
# Requirement already satisfied: setuptools in c:\users\mjnie\anaconda3\lib\site-packages (from autobahn>=21.2.1->binance-connector) (50.3.1.post20201107)
# Requirement already satisfied: txaio>=21.2.1 in c:\users\mjnie\anaconda3\lib\site-packages (from autobahn>=21.2.1->binance-connector) (22.2.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\mjnie\anaconda3\lib\site-packages (from cryptography->service-identity>=21.1.0->binance-connector) (1.14.3)
# Requirement already satisfied: pycparser in c:\users\mjnie\anaconda3\lib\site-packages (from cffi>=1.12->cryptography->service-identity>=21.1.0->binance-connector) (2.20)
# Requirement already satisfied: psycopg2 in c:\users\mjnie\anaconda3\lib\site-packages (2.9.3)

# %%
#import librariers
from binance.spot import Spot as Client
import pandas as pd
import numpy as np



#url to access binance api
base_url = "https://api.binance.com"

#create Client to access API
spot_client = Client(base_url=base_url)

# %%
exchange_info = spot_client.exchange_info()
exchange_info
# Out:
# {'timezone': 'UTC',
#  'serverTime': 1648556561087,
#  'rateLimits': [{'rateLimitType': 'REQUEST_WEIGHT',
#    'interval': 'MINUTE',
#    'intervalNum': 1,
#    'limit': 1200},
#   {'rateLimitType': 'ORDERS',
#    'interval': 'SECOND',
#    'intervalNum': 10,
#    'limit': 50},
#   {'rateLimitType': 'ORDERS',
#    'interval': 'DAY',
#    'intervalNum': 1,
#    'limit': 160000},
#   {'rateLimitType': 'RAW_REQUESTS',
#    'interval': 'MINUTE',
#    'intervalNum': 5,
#    'limit': 6100}],
#  'exchangeFilters': [],
#  'symbols': [{'symbol': 'ETHBTC',
#    'status': 'TRADING',
#    'baseAsset': 'ETH',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '922327.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '1390.14255455',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'LTCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'LTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '7068.29342807',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'BNBBTC',
#    'status': 'TRADING',
#    'baseAsset': 'BNB',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '15510.89139819',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'NEOBTC',
#    'status': 'TRADING',
#    'baseAsset': 'NEO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '7339.71025017',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'QTUMETH',
#    'status': 'TRADING',
#    'baseAsset': 'QTUM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '8940.10639332',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'EOSETH',
#    'status': 'TRADING',
#    'baseAsset': 'EOS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '40108.74493055',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'SNTETH',
#    'status': 'TRADING',
#    'baseAsset': 'SNT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '468574.58165392',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BNTETH',
#    'status': 'TRADING',
#    'baseAsset': 'BNT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '18140.69235580',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BCCBTC',
#    'status': 'BREAK',
#    'baseAsset': 'BCC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'GASBTC',
#    'status': 'TRADING',
#    'baseAsset': 'GAS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '14098.89451007',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BNBETH',
#    'status': 'TRADING',
#    'baseAsset': 'BNB',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '9000000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '3637.78161041',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'BTCUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'BTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.01000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '0.01000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00001000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00001000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '147.68345567',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'ETHUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'ETH',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.01000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '0.01000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '1812.96508867',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'HSRBTC',
#    'status': 'BREAK',
#    'baseAsset': 'HSR',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'OAXETH',
#    'status': 'BREAK',
#    'baseAsset': 'OAX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '579591.88919668',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'DNTETH',
#    'status': 'BREAK',
#    'baseAsset': 'DNT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '4194220.05124836',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'MCOETH',
#    'status': 'BREAK',
#    'baseAsset': 'MCO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '6660.95529820',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'ICNETH',
#    'status': 'BREAK',
#    'baseAsset': 'ICN',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'MCOBTC',
#    'status': 'BREAK',
#    'baseAsset': 'MCO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '27097.31944518',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'WTCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'WTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '9000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '77939.76944444',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'WTCETH',
#    'status': 'BREAK',
#    'baseAsset': 'WTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '28248.67398611',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'LRCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'LRC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '329548.42043085',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'LRCETH',
#    'status': 'TRADING',
#    'baseAsset': 'LRC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '103523.73870743',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'QTUMBTC',
#    'status': 'TRADING',
#    'baseAsset': 'QTUM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '10852.98464211',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'YOYOBTC',
#    'status': 'BREAK',
#    'baseAsset': 'YOYO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '27238301.91805555',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'OMGBTC',
#    'status': 'TRADING',
#    'baseAsset': 'OMG',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '25402.42585128',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'OMGETH',
#    'status': 'TRADING',
#    'baseAsset': 'OMG',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '12160.24562500',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'ZRXBTC',
#    'status': 'TRADING',
#    'baseAsset': 'ZRX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '148808.26963168',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'ZRXETH',
#    'status': 'TRADING',
#    'baseAsset': 'ZRX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '69984.84016678',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'STRATBTC',
#    'status': 'BREAK',
#    'baseAsset': 'STRAT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '222217.01315789',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'STRATETH',
#    'status': 'BREAK',
#    'baseAsset': 'STRAT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '75043.65373961',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'SNGLSBTC',
#    'status': 'BREAK',
#    'baseAsset': 'SNGLS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '69235100.97256515',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'SNGLSETH',
#    'status': 'BREAK',
#    'baseAsset': 'SNGLS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '6821000.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BQXBTC',
#    'status': 'BREAK',
#    'baseAsset': 'BQX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '106190.15178571',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BQXETH',
#    'status': 'BREAK',
#    'baseAsset': 'BQX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '10.00000000',
# ...
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '57353.40812500',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'SUSHIBUSD',
#    'status': 'TRADING',
#    'baseAsset': 'SUSHI',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BUSD',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00100000',
#      'maxPrice': '10000.00000000',
#      'tickSize': '0.00100000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '52734.14097222',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'SUSHIUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'SUSHI',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00100000',
#      'maxPrice': '10000.00000000',
#      'tickSize': '0.00100000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '197986.20771369',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'YFIIBNB',
#    'status': 'TRADING',
#    'baseAsset': 'YFII',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BNB',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.01000000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.01000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '90000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.05000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '8.55463842',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'YFIIBTC',
#    'status': 'TRADING',
#    'baseAsset': 'YFII',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '20.67317555',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'YFIIBUSD',
#    'status': 'TRADING',
#    'baseAsset': 'YFII',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BUSD',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '1.00000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '1.00000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '12.24662411',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'YFIIUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'YFII',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '1.00000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '1.00000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '51.03268658',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'KSMBNB',
#    'status': 'TRADING',
#    'baseAsset': 'KSM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BNB',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '10000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '900000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.05000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '227.55626059',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'KSMBTC',
#    'status': 'TRADING',
#    'baseAsset': 'KSM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '10000000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '668.54299166',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'KSMBUSD',
#    'status': 'TRADING',
#    'baseAsset': 'KSM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BUSD',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.10000000',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.10000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '900000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '598.47197081',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'KSMUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'KSM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.10000000',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.10000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '900000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '3721.32859833',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'EGLDBNB',
#    'status': 'TRADING',
#    'baseAsset': 'EGLD',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BNB',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'allowTrailingStop': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '10000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '900000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.05000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '442.58646773',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   ...]}

# %%
symbols = pd.DataFrame(exchange_info["symbols"])
symbols
# Out:
#           symbol   status baseAsset  baseAssetPrecision quoteAsset  \
# 0         ETHBTC  TRADING       ETH                   8        BTC
# 1         LTCBTC  TRADING       LTC                   8        BTC
# 2         BNBBTC  TRADING       BNB                   8        BTC
# 3         NEOBTC  TRADING       NEO                   8        BTC
# 4        QTUMETH  TRADING      QTUM                   8        ETH
# ...          ...      ...       ...                 ...        ...
# 1985      APEBNB  TRADING       APE                   8        BNB
# 1986      GMTBRL  TRADING       GMT                   8        BRL
# 1987      GMTETH  TRADING       GMT                   8        ETH
# 1988    JASMYTRY  TRADING     JASMY                   8        TRY
# 1989  SANTOSBUSD  TRADING    SANTOS                   8       BUSD
#
#       quotePrecision  quoteAssetPrecision  baseCommissionPrecision  \
# 0                  8                    8                        8
# 1                  8                    8                        8
# 2                  8                    8                        8
# 3                  8                    8                        8
# 4                  8                    8                        8
# ...              ...                  ...                      ...
# 1985               8                    8                        8
# 1986               8                    8                        8
# 1987               8                    8                        8
# 1988               8                    8                        8
# 1989               8                    8                        8
#
#       quoteCommissionPrecision  \
# 0                            8
# 1                            8
# 2                            8
# 3                            8
# 4                            8
# ...                        ...
# 1985                         8
# 1986                         8
# 1987                         8
# 1988                         8
# 1989                         8
#
#                                              orderTypes  icebergAllowed  \
# 0     [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
# 1     [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
# 2     [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
# 3     [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
# 4     [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
# ...                                                 ...             ...
# 1985  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
# 1986  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
# 1987  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
# 1988  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
# 1989  [LIMIT, LIMIT_MAKER, MARKET, STOP_LOSS_LIMIT, ...            True
#
#       ocoAllowed  quoteOrderQtyMarketAllowed  allowTrailingStop  \
# 0           True                        True              False
# 1           True                        True              False
# 2           True                        True              False
# 3           True                        True              False
# 4           True                        True              False
# ...          ...                         ...                ...
# 1985        True                        True              False
# 1986        True                        True              False
# 1987        True                        True              False
# 1988        True                        True              False
# 1989        True                        True              False
#
#       isSpotTradingAllowed  isMarginTradingAllowed  \
# 0                     True                    True
# 1                     True                    True
# 2                     True                    True
# 3                     True                    True
# 4                     True                   False
# ...                    ...                     ...
# 1985                  True                   False
# 1986                  True                   False
# 1987                  True                   False
# 1988                  True                   False
# 1989                  True                   False
#
#                                                 filters     permissions
# 0     [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  [SPOT, MARGIN]
# 1     [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  [SPOT, MARGIN]
# 2     [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  [SPOT, MARGIN]
# 3     [{'filterType': 'PRICE_FILTER', 'minPrice': '0...  [SPOT, MARGIN]
# 4     [{'filterType': 'PRICE_FILTER', 'minPrice': '0...          [SPOT]
# ...                                                 ...             ...
# 1985  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...          [SPOT]
# 1986  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...          [SPOT]
# 1987  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...          [SPOT]
# 1988  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...          [SPOT]
# 1989  [{'filterType': 'PRICE_FILTER', 'minPrice': '0...          [SPOT]
#
# [1990 rows x 18 columns]

# %%
# Access historical prices
btcusd_history = spot_client.klines("BTCUSDT", "1d", limit=100)

# show as DataFrame
columns=['time', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 
         'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']
btcusd_history_df = pd.DataFrame(btcusd_history, columns=columns)
btcusd_history_df['time'] = pd.to_datetime(btcusd_history_df['time'], unit='ms')

display(btcusd_history_df)
# Out:
#          time            open            high             low           close  \
# 0  2021-12-23  48588.17000000  51375.00000000  47920.42000000  50838.81000000
# 1  2021-12-24  50838.82000000  51810.00000000  50384.43000000  50820.00000000
# 2  2021-12-25  50819.99000000  51156.23000000  50142.32000000  50399.66000000
# 3  2021-12-26  50399.67000000  51280.00000000  49412.00000000  50775.49000000
# 4  2021-12-27  50775.48000000  52088.00000000  50449.00000000  50701.44000000
# ..        ...             ...             ...             ...             ...
# 95 2022-03-28  46827.76000000  48189.84000000  46663.56000000  47122.21000000
# 96 2022-03-29  47122.21000000  48096.47000000  46950.85000000  47434.80000000
# 97 2022-03-30  47434.79000000  47700.22000000  46445.42000000  47067.99000000
# 98 2022-03-31  47067.99000000  47600.00000000  45200.00000000  45510.34000000
# 99 2022-04-01  45510.35000000  46720.09000000  44200.00000000  46566.99000000
#
#             volume     close_time   quote_asset_volume  number_of_trades  \
# 0   35192.54046000  1640303999999  1738129830.78145220           1176050
# 1   31684.84269000  1640390399999  1618089927.28100640           1075177
# 2   19135.51613000  1640476799999   971491029.13082400            766979
# 3   22569.88914000  1640563199999  1132200241.56241820            797133
# 4   28783.57561000  1640649599999  1471626727.60451720           1008993
# ..             ...            ...                  ...               ...
# 95  58949.26140000  1648511999999  2789898402.61657610           1498975
# 96  36772.28457000  1648598399999  1748600385.45023520           1095678
# 97  40947.20850000  1648684799999  1932152559.88311230           1081607
# 98  48645.12667000  1648771199999  2262485160.56858420           1290541
# 99  43457.80109000  1648857599999  1962925459.67150630            974057
#
#    taker_buy_base_asset_volume taker_buy_quote_asset_volume ignore
# 0               17397.67034000           859605116.67975700      0
# 1               15108.36362000           771557283.62606790      0
# 2                9928.30266000           504102529.52889820      0
# 3               11285.69707000           566374786.71606860      0
# 4               14431.77595000           738150090.13157020      0
# ..                         ...                          ...    ...
# 95              29097.75719000          1377280753.97272760      0
# 96              18192.37420000           865179145.17564560      0
# 97              20896.43399000           985946938.56827850      0
# 98              22879.47328000          1064278670.64261090      0
# 99              21629.90276000           977349894.09660800      0
#
# [100 rows x 12 columns]

# %%
# Access historical prices
ethusd_history = spot_client.klines("ETHUSDT", "1d", limit=100)

# show as DataFrame
columns=['time', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 
         'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']
ethusd_history_df = pd.DataFrame(ethusd_history, columns=columns)
ethusd_history_df['time'] = pd.to_datetime(ethusd_history_df['time'], unit='ms')

display(ethusd_history_df)
# Out:
#          time           open           high            low          close  \
# 0  2021-12-23  3979.51000000  4150.00000000  3893.23000000  4111.41000000
# 1  2021-12-24  4111.41000000  4134.84000000  4017.17000000  4046.36000000
# 2  2021-12-25  4046.35000000  4137.91000000  4018.62000000  4094.83000000
# 3  2021-12-26  4094.36000000  4105.00000000  4000.00000000  4063.56000000
# 4  2021-12-27  4063.57000000  4127.46000000  4031.00000000  4037.23000000
# ..        ...            ...            ...            ...            ...
# 95 2022-03-28  3295.65000000  3431.15000000  3275.01000000  3332.92000000
# 96 2022-03-29  3332.91000000  3481.87000000  3329.68000000  3400.51000000
# 97 2022-03-30  3400.51000000  3446.90000000  3331.84000000  3385.79000000
# 98 2022-03-31  3385.80000000  3444.83000000  3261.35000000  3281.51000000
# 99 2022-04-01  3281.51000000  3454.36000000  3210.68000000  3441.69000000
#
#              volume     close_time   quote_asset_volume  number_of_trades  \
# 0   380207.81660000  1640303999999  1525274496.50604700            911905
# 1   230833.16610000  1640390399999   943702137.85492300            593513
# 2   208126.88050000  1640476799999   846912042.12908200            515115
# 3   189309.25500000  1640563199999   767315615.26886600            496076
# 4   222140.39230000  1640649599999   905337679.72623500            557125
# ..              ...            ...                  ...               ...
# 95  527237.11330000  1648511999999  1766636914.05138400            964079
# 96  465899.82260000  1648598399999  1590016971.38855800            884317
# 97  356082.52310000  1648684799999  1206555998.56790400            675015
# 98  455091.23950000  1648771199999  1526047563.60251500            770564
# 99  388284.16030000  1648857599999  1284487470.67603300            613255
#
#    taker_buy_base_asset_volume taker_buy_quote_asset_volume ignore
# 0              194409.23590000           780346994.88613200      0
# 1              108806.89750000           444971527.99616500      0
# 2              100652.69260000           409702072.86923400      0
# 3               88120.23950000           357288552.81829400      0
# 4              105449.44410000           429903165.78709300      0
# ..                         ...                          ...    ...
# 95             270854.19570000           907605017.55763000      0
# 96             231156.95700000           789137059.00101900      0
# 97             181916.41480000           616519459.51942800      0
# 98             216602.75050000           726452427.30871800      0
# 99             197570.88800000           654084115.13182100      0
#
# [100 rows x 12 columns]

# %%
# Access historical prices
ltcusd_history = spot_client.klines("LTCUSDT", "1d", limit=100)

# show as DataFrame
columns=['time', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 
         'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']
ltcusd_history_df = pd.DataFrame(ltcusd_history, columns=columns)
ltcusd_history_df['time'] = pd.to_datetime(ltcusd_history_df['time'], unit='ms')

display(ltcusd_history_df)
# Out:
#          time          open          high           low         close  \
# 0  2021-12-23  155.40000000  165.20000000  153.00000000  163.60000000
# 1  2021-12-24  163.60000000  166.80000000  160.10000000  161.20000000
# 2  2021-12-25  161.20000000  163.60000000  157.30000000  157.80000000
# 3  2021-12-26  157.80000000  158.40000000  152.60000000  155.70000000
# 4  2021-12-27  155.80000000  161.30000000  154.40000000  155.90000000
# ..        ...           ...           ...           ...           ...
# 95 2022-03-28  129.70000000  132.60000000  126.70000000  127.60000000
# 96 2022-03-29  127.60000000  132.00000000  127.00000000  130.10000000
# 97 2022-03-30  130.00000000  134.10000000  125.80000000  131.10000000
# 98 2022-03-31  131.10000000  132.90000000  121.10000000  123.80000000
# 99 2022-04-01  123.90000000  125.80000000  119.10000000  125.40000000
#
#              volume     close_time  quote_asset_volume  number_of_trades  \
# 0   521673.02100000  1640303999999   82928184.39030000            158956
# 1   411411.85600000  1640390399999   67263215.43170000            131373
# 2   456068.09400000  1640476799999   73267865.90720000            107574
# 3   887961.05900000  1640563199999  137926395.70560000            189278
# 4   463741.77000000  1640649599999   73291017.80660000            137520
# ..              ...            ...                 ...               ...
# 95  485087.18100000  1648511999999   63427481.58600000            115694
# 96  402240.88800000  1648598399999   52122445.08610000             93018
# 97  469285.07500000  1648684799999   61290275.33570000            113830
# 98  925439.97600000  1648771199999  117415876.07080000            165734
# 99  329624.50200000  1648857599999   40392151.58480000             68864
#
#    taker_buy_base_asset_volume taker_buy_quote_asset_volume ignore
# 0              273433.81200000            43498366.08960000      0
# 1              194481.43400000            31819944.61910000      0
# 2              205038.77300000            32983365.77290000      0
# 3              383136.23000000            59558099.54490000      0
# 4              237167.57700000            37496416.24320000      0
# ..                         ...                          ...    ...
# 95             243095.45700000            31801620.50080000      0
# 96             198052.45900000            25673890.57000000      0
# 97             237595.15600000            31043956.79740000      0
# 98             521048.88800000            66233633.18480000      0
# 99             161631.43500000            19825906.57250000      0
#
# [100 rows x 12 columns]

# %%
# Access historical prices
adausd_history = spot_client.klines("ADAUSDT", "1d", limit=100)

# show as DataFrame
columns=['time', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 
         'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']
adausd_history_df = pd.DataFrame(adausd_history, columns=columns)
adausd_history_df['time'] = pd.to_datetime(adausd_history_df['time'], unit='ms')

display(adausd_history_df)
# Out:
#          time        open        high         low       close  \
# 0  2021-12-23  1.32700000  1.49000000  1.30700000  1.47500000
# 1  2021-12-24  1.47500000  1.49100000  1.38100000  1.39200000
# 2  2021-12-25  1.39300000  1.46000000  1.38100000  1.45200000
# 3  2021-12-26  1.45300000  1.46700000  1.40700000  1.45500000
# 4  2021-12-27  1.45500000  1.59400000  1.45000000  1.51600000
# ..        ...         ...         ...         ...         ...
# 95 2022-03-28  1.18400000  1.24600000  1.15700000  1.17000000
# 96 2022-03-29  1.17000000  1.24300000  1.16600000  1.19100000
# 97 2022-03-30  1.19100000  1.21800000  1.16100000  1.18900000
# 98 2022-03-31  1.18900000  1.22800000  1.13300000  1.14100000
# 99 2022-04-01  1.14100000  1.17500000  1.10400000  1.17100000
#
#                 volume     close_time  quote_asset_volume  number_of_trades  \
# 0   216795659.80000000  1640303999999  302005401.18160000            554345
# 1   126360588.30000000  1640390399999  182041800.82630000            334001
# 2    87587873.90000000  1640476799999  125105131.84500000            208614
# 3   103769249.90000000  1640563199999  149590055.60230000            237124
# 4   181165265.80000000  1640649599999  278857052.85180000            530512
# ..                 ...            ...                 ...               ...
# 95  261105698.60000000  1648511999999  313807434.48560000            517027
# 96  180298618.00000000  1648598399999  217154215.41500000            341275
# 97  146032640.30000000  1648684799999  173764772.78650000            233353
# 98  177164788.10000000  1648771199999  209017789.90700000            307148
# 99  145842724.50000000  1648857599999  165837326.48620000            211105
#
#    taker_buy_base_asset_volume taker_buy_quote_asset_volume ignore
# 0           106210779.80000000           147924112.43740000      0
# 1            62015167.30000000            89385902.97170000      0
# 2            44566595.50000000            63666594.52200000      0
# 3            51587279.50000000            74386557.94880000      0
# 4            89525961.00000000           137801185.74480000      0
# ..                         ...                          ...    ...
# 95          130753524.40000000           157242155.88600000      0
# 96           87102380.10000000           104947290.20190000      0
# 97           72207436.30000000            85956392.26100000      0
# 98           85926940.40000000           101514333.82120000      0
# 99           68759398.60000000            78243555.82470000      0
#
# [100 rows x 12 columns]

# %%
#Connection to datalakecrypto
import psycopg2

# %%
try: 
    conn = psycopg2.connect("host=X dbname=X user=X password=X")
except psycopg2.Error as e: 
    print("Error: Could not make connection to the Postgres database")
    print(e)

# %%
try: 
    cur = conn.cursor()
except psycopg2.Error as e: 
    print("Error: Could not get curser to the Database")
    print(e)
    
# Auto commit is very important
conn.set_session(autocommit=True)

# %%
#creating table btcusd_history
cur.execute("CREATE TABLE IF NOT EXISTS btcusd_history (time date, open float, high float, low float, close float, volume float, close_time bigint, quote_asset_volume float, number_of_trades bigint, taker_buy_base_asset_volume float, taker_buy_quote_asset_volume float, ignore int);")

# %%
cur.execute("TRUNCATE TABLE btcusd_history")

# %%
#In this step, I write a SQL query within my Python code to retrieve data from my database.

def add_data(time, open, high, low, close, volume, close_time, quote_asset_volume, number_of_trades, taker_buy_base_asset_volume, taker_buy_quote_asset_volume, ignore):
    try:
        #SQL statement with VALUE %s. All data has to be transmitted by %s, doesnt matter if string or float.
        statement = "INSERT INTO btcusd_history (time, open, high, low, close, volume, close_time, quote_asset_volume, number_of_trades, taker_buy_base_asset_volume, taker_buy_quote_asset_volume, ignore) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
        data = (time, open, high, low, close, volume, close_time, quote_asset_volume, number_of_trades, taker_buy_base_asset_volume, taker_buy_quote_asset_volume, ignore)
        cur.execute(statement, data)
        print("Successfully added entry to database") #check-message
    except psycopg2.Error as e: #In the except block, which only executes when there is an exception, declare database.Error as e. This variable will hold information about the type of exception that occurs.
        print(f"Error adding entry to database: {e}")

# %%
for pos, d in btcusd_history_df.iterrows():
    add_data(
        d["time"],
        d["open"],
        d["high"],
        d["low"],
        d["close"],
        d["volume"],
        d["close_time"],
        d["quote_asset_volume"],
        d["number_of_trades"],
        d["taker_buy_base_asset_volume"],
        d["taker_buy_quote_asset_volume"],
        d["ignore"]
            )
# Out:
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database

# %%
#creating table ethusd_history
cur.execute("CREATE TABLE IF NOT EXISTS ethusd_history (time date, open float, high float, low float, close float, volume float, close_time bigint, quote_asset_volume float, number_of_trades bigint, taker_buy_base_asset_volume float, taker_buy_quote_asset_volume float, ignore int);")

# %%
cur.execute("TRUNCATE TABLE ethusd_history")

# %%
#In this step, I write a SQL query within my Python code to retrieve data from my database.

def add_data(time, open, high, low, close, volume, close_time, quote_asset_volume, number_of_trades, taker_buy_base_asset_volume, taker_buy_quote_asset_volume, ignore):
    try:
        #SQL statement with VALUE %s. All data has to be transmitted by %s, doesnt matter if string or float.
        statement = "INSERT INTO ethusd_history (time, open, high, low, close, volume, close_time, quote_asset_volume, number_of_trades, taker_buy_base_asset_volume, taker_buy_quote_asset_volume, ignore) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
        data = (time, open, high, low, close, volume, close_time, quote_asset_volume, number_of_trades, taker_buy_base_asset_volume, taker_buy_quote_asset_volume, ignore)
        cur.execute(statement, data)
        print("Successfully added entry to database") #check-message
    except psycopg2.Error as e: #In the except block, which only executes when there is an exception, declare database.Error as e. This variable will hold information about the type of exception that occurs.
        print(f"Error adding entry to database: {e}")

# %%
for pos, d in ethusd_history_df.iterrows():
    add_data(
        d["time"],
        d["open"],
        d["high"],
        d["low"],
        d["close"],
        d["volume"],
        d["close_time"],
        d["quote_asset_volume"],
        d["number_of_trades"],
        d["taker_buy_base_asset_volume"],
        d["taker_buy_quote_asset_volume"],
        d["ignore"]
            )
# Out:
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database

# %%
#creating table ltcusd_history
cur.execute("CREATE TABLE IF NOT EXISTS ltcusd_history (time date, open float, high float, low float, close float, volume float, close_time bigint, quote_asset_volume float, number_of_trades bigint, taker_buy_base_asset_volume float, taker_buy_quote_asset_volume float, ignore int);")

# %%
cur.execute("TRUNCATE TABLE ltcusd_history")

# %%
#In this step, I write a SQL query within my Python code to retrieve data from my database.

def add_data(time, open, high, low, close, volume, close_time, quote_asset_volume, number_of_trades, taker_buy_base_asset_volume, taker_buy_quote_asset_volume, ignore):
    try:
        #SQL statement with VALUE %s. All data has to be transmitted by %s, doesnt matter if string or float.
        statement = "INSERT INTO ltcusd_history (time, open, high, low, close, volume, close_time, quote_asset_volume, number_of_trades, taker_buy_base_asset_volume, taker_buy_quote_asset_volume, ignore) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
        data = (time, open, high, low, close, volume, close_time, quote_asset_volume, number_of_trades, taker_buy_base_asset_volume, taker_buy_quote_asset_volume, ignore)
        cur.execute(statement, data)
        print("Successfully added entry to database") #check-message
    except psycopg2.Error as e: #In the except block, which only executes when there is an exception, declare database.Error as e. This variable will hold information about the type of exception that occurs.
        print(f"Error adding entry to database: {e}")

# %%
for pos, d in ltcusd_history_df.iterrows():
    add_data(
        d["time"],
        d["open"],
        d["high"],
        d["low"],
        d["close"],
        d["volume"],
        d["close_time"],
        d["quote_asset_volume"],
        d["number_of_trades"],
        d["taker_buy_base_asset_volume"],
        d["taker_buy_quote_asset_volume"],
        d["ignore"]
            )
# Out:
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database

# %%
# Out:
# [(100,)]

# %%
#creating table adausd_history
cur.execute("CREATE TABLE IF NOT EXISTS adausd_history (time date, open float, high float, low float, close float, volume float, close_time bigint, quote_asset_volume float, number_of_trades bigint, taker_buy_base_asset_volume float, taker_buy_quote_asset_volume float, ignore int);")

# %%
cur.execute("TRUNCATE TABLE adausd_history")

# %%
#In this step, I write a SQL query within my Python code to retrieve data from my database.

def add_data(time, open, high, low, close, volume, close_time, quote_asset_volume, number_of_trades, taker_buy_base_asset_volume, taker_buy_quote_asset_volume, ignore):
    try:
        #SQL statement with VALUE %s. All data has to be transmitted by %s, doesnt matter if string or float.
        statement = "INSERT INTO adausd_history (time, open, high, low, close, volume, close_time, quote_asset_volume, number_of_trades, taker_buy_base_asset_volume, taker_buy_quote_asset_volume, ignore) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
        data = (time, open, high, low, close, volume, close_time, quote_asset_volume, number_of_trades, taker_buy_base_asset_volume, taker_buy_quote_asset_volume, ignore)
        cur.execute(statement, data)
        print("Successfully added entry to database") #check-message
    except psycopg2.Error as e: #In the except block, which only executes when there is an exception, declare database.Error as e. This variable will hold information about the type of exception that occurs.
        print(f"Error adding entry to database: {e}")

# %%
for pos, d in adausd_history_df.iterrows():
    add_data(
        d["time"],
        d["open"],
        d["high"],
        d["low"],
        d["close"],
        d["volume"],
        d["close_time"],
        d["quote_asset_volume"],
        d["number_of_trades"],
        d["taker_buy_base_asset_volume"],
        d["taker_buy_quote_asset_volume"],
        d["ignore"]
            )
# Out:
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database
# Successfully added entry to database

# %%
cur.execute("select count(*) from adausd_history;")
print(cur.fetchall())
# Out:
# [(109,)]

# %%
try: 
    cur.execute("SELECT * FROM adausd_history;")
except psycopg2.Error as e: 
    print("Error: select *")
    print (e)

row = cur.fetchone()
while row:
   print(row)
   row = cur.fetchone()
# Out:
# (datetime.date(2021, 12, 23), 1.327, 1.49, 1.307, 1.475, 216795659.8, 1640303999999, 302005401.1816, 554345, 106210779.8, 147924112.4374, 0)
# (datetime.date(2021, 12, 24), 1.475, 1.491, 1.381, 1.392, 126360588.3, 1640390399999, 182041800.8263, 334001, 62015167.3, 89385902.9717, 0)
# (datetime.date(2021, 12, 25), 1.393, 1.46, 1.381, 1.452, 87587873.9, 1640476799999, 125105131.845, 208614, 44566595.5, 63666594.522, 0)
# (datetime.date(2021, 12, 26), 1.453, 1.467, 1.407, 1.455, 103769249.9, 1640563199999, 149590055.6023, 237124, 51587279.5, 74386557.9488, 0)
# (datetime.date(2021, 12, 27), 1.455, 1.594, 1.45, 1.516, 181165265.8, 1640649599999, 278857052.8518, 530512, 89525961.0, 137801185.7448, 0)
# (datetime.date(2021, 12, 28), 1.516, 1.54, 1.376, 1.4, 233458767.4, 1640735999999, 341026716.3522, 532040, 111940957.7, 163568082.3167, 0)
# (datetime.date(2021, 12, 29), 1.4, 1.438, 1.323, 1.332, 151404808.3, 1640822399999, 209084760.1348, 331818, 73590732.8, 101656381.198, 0)
# (datetime.date(2021, 12, 30), 1.333, 1.378, 1.297, 1.359, 134171567.8, 1640908799999, 179821991.0688, 262385, 66584329.7, 89274226.8081, 0)
# (datetime.date(2021, 12, 31), 1.359, 1.383, 1.281, 1.308, 120612337.3, 1640995199999, 161322991.5909, 246500, 58428953.2, 78173093.0628, 0)
# (datetime.date(2022, 1, 1), 1.308, 1.38, 1.306, 1.38, 69007607.5, 1641081599999, 92211737.9666, 159578, 35543023.2, 47500596.5123, 0)
# (datetime.date(2022, 1, 2), 1.379, 1.391, 1.342, 1.377, 81011860.4, 1641167999999, 110645055.5902, 175248, 40618946.7, 55484105.9652, 0)
# (datetime.date(2022, 1, 3), 1.378, 1.378, 1.31, 1.319, 87155825.9, 1641254399999, 117269967.5736, 191931, 41893901.4, 56358992.3813, 0)
# (datetime.date(2022, 1, 4), 1.319, 1.352, 1.295, 1.309, 94479305.9, 1641340799999, 124982226.7397, 216349, 46205791.4, 61169674.5822, 0)
# (datetime.date(2022, 1, 5), 1.31, 1.353, 1.193, 1.23, 158740088.2, 1641427199999, 203778648.559, 365590, 76050733.2, 97718121.8413, 0)
# (datetime.date(2022, 1, 6), 1.23, 1.297, 1.186, 1.28, 175754407.6, 1641513599999, 216590054.1071, 361052, 88970774.4, 109746849.4002, 0)
# (datetime.date(2022, 1, 7), 1.279, 1.285, 1.189, 1.21, 209806013.2, 1641599999999, 256808689.2376, 412091, 100722433.2, 123355599.3005, 0)
# (datetime.date(2022, 1, 8), 1.209, 1.254, 1.124, 1.181, 169730473.68, 1641686399999, 201840755.440639, 359202, 82915127.24, 98682750.22704, 0)
# (datetime.date(2022, 1, 9), 1.182, 1.206, 1.147, 1.17, 114093699.4, 1641772799999, 134353467.7772, 231040, 56212732.5, 66207531.3632, 0)
